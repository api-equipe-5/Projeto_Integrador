# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel ('STG_MVT_CRD.xlsx')

# %%
df
# Out:
#     ID_STG_MVT_CRD  VLR_SDO_UTZ_CRD_RTO   VLR_TOT_FAT   VLR_MIM_FAT  \
# 0                1                  NaN           NaN           NaN
# 1                2                  NaN           NaN           NaN
# 2                3                  NaN           NaN           NaN
# 3                4                  NaN           NaN           NaN
# 4                5                  NaN           NaN           NaN
# 5                6                  NaN           NaN           NaN
# 6                7                  NaN           NaN           NaN
# 7                8                  NaN           NaN           NaN
# 8                9                  NaN           NaN           NaN
# 9               10         2.181758e+10           NaN           NaN
# 10              11                  NaN           NaN           NaN
# 11              12                  NaN           NaN           NaN
# 12              13                  NaN           NaN           NaN
# 13              14                  NaN           NaN           NaN
# 14              15                  NaN  1.932767e+12  6.071738e+11
#
#      VLR_PCL_FAT  QTD_CLI_CAD_POS   QTD_MVT DES_TIP_PSS  ID_FNT_ITT COD_MDL  \
# 0   4.595517e+10            37186    677272           F          67     C01
# 1   7.387237e+10           307070   2741111           F          67     B99
# 2   2.868181e+09              601      1964           F          67     B01
# 3   6.111251e+10            18820    244041           F          67     B03
# 4   2.152609e+06                2         4           F          67     F01
# 5   4.607337e+08               33       329           F          67     B07
# 6   2.638331e+11           721836  10020532           F          67     A04
# 7   1.838029e+11           135773   1797516           F          67     B05
# 8   9.738713e+08             5061     38003           F          67     A05
# 9            NaN           194378    194921           F          67     E01
# 10  9.496722e+09             1890    123559           F          67     G01
# 11  3.556795e+11           494442  19241809           F          67     A01
# 12  1.834447e+09            46495    230867           F          67     A99
# 13  1.733950e+08               43       330           F          67     B06
# 14           NaN          1840240  21748501           F          67     D01
#
#    DAT_RSS_FNT_ITT              DAT_INC_DBO
# 0       2020-01-16  2020-01-17 17:49:17.524
# 1       2020-01-16  2020-01-17 17:49:17.524
# 2       2020-01-16  2020-01-17 17:49:17.524
# 3       2020-01-16  2020-01-17 17:49:17.524
# 4       2020-01-16  2020-01-17 17:49:17.524
# 5       2020-01-16  2020-01-17 17:49:17.524
# 6       2020-01-16  2020-01-17 17:49:17.524
# 7       2020-01-16  2020-01-17 17:49:17.524
# 8       2020-01-16  2020-01-17 17:49:17.524
# 9       2020-01-16  2020-01-17 17:49:17.524
# 10      2020-01-16  2020-01-17 17:49:17.524
# 11      2020-01-16  2020-01-17 17:49:17.524
# 12      2020-01-16  2020-01-17 17:49:17.524
# 13      2020-01-16  2020-01-17 17:49:17.524
# 14      2020-01-16  2020-01-17 17:49:17.524

# %%
df.plot(kind='bar',x='COD_MDL', y='VLR_PCL_FAT', figsize = (15,8));

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_STG_MVT_CRD       15 non-null     int64
#  1   VLR_SDO_UTZ_CRD_RTO  1 non-null      float64
#  2   VLR_TOT_FAT          1 non-null      float64
#  3   VLR_MIM_FAT          1 non-null      float64
#  4   VLR_PCL_FAT          13 non-null     float64
#  5   QTD_CLI_CAD_POS      15 non-null     int64
#  6   QTD_MVT              15 non-null     int64
#  7   DES_TIP_PSS          15 non-null     object
#  8   ID_FNT_ITT           15 non-null     int64
#  9   COD_MDL              15 non-null     object
#  10  DAT_RSS_FNT_ITT      15 non-null     object
#  11  DAT_INC_DBO          15 non-null     object
# dtypes: float64(4), int64(4), object(4)
# memory usage: 1.5+ KB

# %%
df = df.replace(np.nan, 0)
df
# Out:
#     ID_STG_MVT_CRD  VLR_SDO_UTZ_CRD_RTO   VLR_TOT_FAT   VLR_MIM_FAT  \
# 0                1         0.000000e+00  0.000000e+00  0.000000e+00
# 1                2         0.000000e+00  0.000000e+00  0.000000e+00
# 2                3         0.000000e+00  0.000000e+00  0.000000e+00
# 3                4         0.000000e+00  0.000000e+00  0.000000e+00
# 4                5         0.000000e+00  0.000000e+00  0.000000e+00
# 5                6         0.000000e+00  0.000000e+00  0.000000e+00
# 6                7         0.000000e+00  0.000000e+00  0.000000e+00
# 7                8         0.000000e+00  0.000000e+00  0.000000e+00
# 8                9         0.000000e+00  0.000000e+00  0.000000e+00
# 9               10         2.181758e+10  0.000000e+00  0.000000e+00
# 10              11         0.000000e+00  0.000000e+00  0.000000e+00
# 11              12         0.000000e+00  0.000000e+00  0.000000e+00
# 12              13         0.000000e+00  0.000000e+00  0.000000e+00
# 13              14         0.000000e+00  0.000000e+00  0.000000e+00
# 14              15         0.000000e+00  1.932767e+12  6.071738e+11
#
#      VLR_PCL_FAT  QTD_CLI_CAD_POS   QTD_MVT DES_TIP_PSS  ID_FNT_ITT COD_MDL  \
# 0   4.595517e+10            37186    677272           F          67     C01
# 1   7.387237e+10           307070   2741111           F          67     B99
# 2   2.868181e+09              601      1964           F          67     B01
# 3   6.111251e+10            18820    244041           F          67     B03
# 4   2.152609e+06                2         4           F          67     F01
# 5   4.607337e+08               33       329           F          67     B07
# 6   2.638331e+11           721836  10020532           F          67     A04
# 7   1.838029e+11           135773   1797516           F          67     B05
# 8   9.738713e+08             5061     38003           F          67     A05
# 9   0.000000e+00           194378    194921           F          67     E01
# 10  9.496722e+09             1890    123559           F          67     G01
# 11  3.556795e+11           494442  19241809           F          67     A01
# 12  1.834447e+09            46495    230867           F          67     A99
# 13  1.733950e+08               43       330           F          67     B06
# 14  0.000000e+00          1840240  21748501           F          67     D01
#
#    DAT_RSS_FNT_ITT              DAT_INC_DBO
# 0       2020-01-16  2020-01-17 17:49:17.524
# 1       2020-01-16  2020-01-17 17:49:17.524
# 2       2020-01-16  2020-01-17 17:49:17.524
# 3       2020-01-16  2020-01-17 17:49:17.524
# 4       2020-01-16  2020-01-17 17:49:17.524
# 5       2020-01-16  2020-01-17 17:49:17.524
# 6       2020-01-16  2020-01-17 17:49:17.524
# 7       2020-01-16  2020-01-17 17:49:17.524
# 8       2020-01-16  2020-01-17 17:49:17.524
# 9       2020-01-16  2020-01-17 17:49:17.524
# 10      2020-01-16  2020-01-17 17:49:17.524
# 11      2020-01-16  2020-01-17 17:49:17.524
# 12      2020-01-16  2020-01-17 17:49:17.524
# 13      2020-01-16  2020-01-17 17:49:17.524
# 14      2020-01-16  2020-01-17 17:49:17.524

# %%
#df.dtypes
#df.VLR_PCL_FAT = df.VLR_PCL_FAT.astype(str)

# %%
df.dtypes
# Out:
# ID_STG_MVT_CRD           int64
# VLR_SDO_UTZ_CRD_RTO    float64
# VLR_TOT_FAT            float64
# VLR_MIM_FAT            float64
# VLR_PCL_FAT            float64
# QTD_CLI_CAD_POS          int64
# QTD_MVT                  int64
# DES_TIP_PSS             object
# ID_FNT_ITT               int64
# COD_MDL                 object
# DAT_RSS_FNT_ITT         object
# DAT_INC_DBO             object
# dtype: object

# %%
for c in df.VLR_PCL_FAT:
    d = c * 0.01
    print (d)
    df.VLR_PCL_FAT = df.VLR_PCL_FAT.replace(c, d)
# Out:
# 459551683.82
# 738723734.09
# 28681807.59
# 611125080.38
# 21526.09
# 4607336.62
# 2638330685.39
# 1838029024.97
# 9738712.71
# 0.0
# 94967215.47
# 3556795492.4900002
# 18344465.14
# 1733950.32
# 0.0

# %%
df
# Out:
#     ID_STG_MVT_CRD  VLR_SDO_UTZ_CRD_RTO   VLR_TOT_FAT   VLR_MIM_FAT  \
# 0                1         0.000000e+00  0.000000e+00  0.000000e+00
# 1                2         0.000000e+00  0.000000e+00  0.000000e+00
# 2                3         0.000000e+00  0.000000e+00  0.000000e+00
# 3                4         0.000000e+00  0.000000e+00  0.000000e+00
# 4                5         0.000000e+00  0.000000e+00  0.000000e+00
# 5                6         0.000000e+00  0.000000e+00  0.000000e+00
# 6                7         0.000000e+00  0.000000e+00  0.000000e+00
# 7                8         0.000000e+00  0.000000e+00  0.000000e+00
# 8                9         0.000000e+00  0.000000e+00  0.000000e+00
# 9               10         2.181758e+10  0.000000e+00  0.000000e+00
# 10              11         0.000000e+00  0.000000e+00  0.000000e+00
# 11              12         0.000000e+00  0.000000e+00  0.000000e+00
# 12              13         0.000000e+00  0.000000e+00  0.000000e+00
# 13              14         0.000000e+00  0.000000e+00  0.000000e+00
# 14              15         0.000000e+00  1.932767e+12  6.071738e+11
#
#      VLR_PCL_FAT  QTD_CLI_CAD_POS   QTD_MVT DES_TIP_PSS  ID_FNT_ITT COD_MDL  \
# 0   4.595517e+08            37186    677272           F          67     C01
# 1   7.387237e+08           307070   2741111           F          67     B99
# 2   2.868181e+07              601      1964           F          67     B01
# 3   6.111251e+08            18820    244041           F          67     B03
# 4   2.152609e+04                2         4           F          67     F01
# 5   4.607337e+06               33       329           F          67     B07
# 6   2.638331e+09           721836  10020532           F          67     A04
# 7   1.838029e+09           135773   1797516           F          67     B05
# 8   9.738713e+06             5061     38003           F          67     A05
# 9   0.000000e+00           194378    194921           F          67     E01
# 10  9.496722e+07             1890    123559           F          67     G01
# 11  3.556795e+09           494442  19241809           F          67     A01
# 12  1.834447e+07            46495    230867           F          67     A99
# 13  1.733950e+06               43       330           F          67     B06
# 14  0.000000e+00          1840240  21748501           F          67     D01
#
#    DAT_RSS_FNT_ITT              DAT_INC_DBO
# 0       2020-01-16  2020-01-17 17:49:17.524
# 1       2020-01-16  2020-01-17 17:49:17.524
# 2       2020-01-16  2020-01-17 17:49:17.524
# 3       2020-01-16  2020-01-17 17:49:17.524
# 4       2020-01-16  2020-01-17 17:49:17.524
# 5       2020-01-16  2020-01-17 17:49:17.524
# 6       2020-01-16  2020-01-17 17:49:17.524
# 7       2020-01-16  2020-01-17 17:49:17.524
# 8       2020-01-16  2020-01-17 17:49:17.524
# 9       2020-01-16  2020-01-17 17:49:17.524
# 10      2020-01-16  2020-01-17 17:49:17.524
# 11      2020-01-16  2020-01-17 17:49:17.524
# 12      2020-01-16  2020-01-17 17:49:17.524
# 13      2020-01-16  2020-01-17 17:49:17.524
# 14      2020-01-16  2020-01-17 17:49:17.524

# %%
#for c in df.VLR_PCL_FAT:
#    d = c[:-4] + '.' + c[-4:-2]
#    print (d)
#    df.VLR_PCL_FAT = df.VLR_PCL_FAT.replace(c, d)

# %%
cd = df.VLR_PCL_FAT.map('R$ {:,.2f}'.format)
#.map('R$ {:,.2f}'.format.map('R$ {:,.2f}'.format))
#("{:3d} {:4d} {:5d}".format(i, i*i, i*i*i))
cd
# Out:
# 0      R$ 4,595,516.84
# 1      R$ 7,387,237.34
# 2        R$ 286,818.08
# 3      R$ 6,111,250.80
# 4            R$ 215.26
# 5         R$ 46,073.37
# 6     R$ 26,383,306.85
# 7     R$ 18,380,290.25
# 8         R$ 97,387.13
# 9              R$ 0.00
# 10       R$ 949,672.15
# 11    R$ 35,567,954.92
# 12       R$ 183,444.65
# 13        R$ 17,339.50
# 14             R$ 0.00
# Name: VLR_PCL_FAT, dtype: object

# %%
df.plot(kind='bar',x='COD_MDL', y='VLR_PCL_FAT', figsize = (15,8));

# %%
df = df    
df.to_excel('output.xlsx')

# %%
cf = pd.read_excel ('STG_MDL.xlsx')

# %%
cf
# Out:
#     ID_STG_MDL COD_MDL                                       DES_MDL  \
# 0           17     E02                      ADIANTAMENTO DEPOSITANTE
# 1           13     B99                         OUTROS FINANCIAMENTOS
# 2           15     D01                             CARTAO DE CREDITO
# 3           19     G01                           TITULOS DESCONTADOS
# 4            2     A02                  EMPRESTIMO - CAPITAL DE GIRO
# 5            3     A04                  EMPRESTIMO - CREDITO PESSOAL
# 6           16     E01             CHEQUE ESPECIAL E CONTA GARANTIDA
# 7            8     B03              FINANCIAMENTO - IMOBILIARIOS SFH
# 8            7     B02      FINANCIAMENTO - IMPORTACAO  E EXPORTACAO
# 9            4     A05                     EMPRESTIMO - MICROCREDITO
# 10           9     B04                  FINANCIAMENTO - MICROCREDITO
# 11          12     B07                 FINANCIAMENTO - ARREENDAMENTO
# 12          18     F01                     AVAIS E FIANCASA HONRADOS
# 13          11     B06          FINANCIAMENTO - IMOBILIARIO (OUTROS)
# 14          14     C01                                     CONSORCIO
# 15           1     A01                       EMPRESTIMO - CONSIGNADO
# 16          10     B05  FINANCIAMENTO - AQUISICAO DE BENS (VEICULOS)
# 17           5     A99                            OUTROS EMPRESTIMOS
# 18           6     B01        FINANCIAMENTO - RURAL E AGROINDUSTRIAL
#
#                 DAT_INC_DBO
# 0   2019-12-19 13:37:34.759
# 1   2019-12-19 13:37:34.759
# 2   2019-12-19 13:37:34.759
# 3   2019-12-19 13:37:34.759
# 4   2019-12-19 13:37:34.759
# 5   2019-12-19 13:37:34.759
# 6   2019-12-19 13:37:34.759
# 7   2019-12-19 13:37:34.759
# 8   2019-12-19 13:37:34.759
# 9   2019-12-19 13:37:34.759
# 10  2019-12-19 13:37:34.759
# 11  2019-12-19 13:37:34.759
# 12  2019-12-19 13:37:34.759
# 13  2019-12-19 13:37:34.759
# 14  2019-12-19 13:37:34.759
# 15  2019-12-19 13:37:34.759
# 16  2019-12-19 13:37:34.759
# 17  2019-12-19 13:37:34.759
# 18  2019-12-19 13:37:34.759

# %%
print (df.COD_MDL, cf.COD_MDL)
# Out:
# 0     C01
# 1     B99
# 2     B01
# 3     B03
# 4     F01
# 5     B07
# 6     A04
# 7     B05
# 8     A05
# 9     E01
# 10    G01
# 11    A01
# 12    A99
# 13    B06
# 14    D01
# Name: COD_MDL, dtype: object 0     E02
# 1     B99
# 2     D01
# 3     G01
# 4     A02
# 5     A04
# 6     E01
# 7     B03
# 8     B02
# 9     A05
# 10    B04
# 11    B07
# 12    F01
# 13    B06
# 14    C01
# 15    A01
# 16    B05
# 17    A99
# 18    B01
# Name: COD_MDL, dtype: object

# %%
g = []

for i in cf.DES_MDL:
    print (i)
    g.append (i)
print (g)
    
for c in range (len(df.COD_MDL)):
    for i in range (len(cf.COD_MDL)):
        if cf.COD_MDL[i] == df.COD_MDL[c]:
            d = g[i]
            print (c, i, d)
            df.COD_MDL[c] = df.COD_MDL[c].replace(df.COD_MDL[c], g[i])
# Out:
# ADIANTAMENTO DEPOSITANTE
# OUTROS FINANCIAMENTOS
# CARTAO DE CREDITO
# TITULOS DESCONTADOS
# EMPRESTIMO - CAPITAL DE GIRO
# EMPRESTIMO - CREDITO PESSOAL
# CHEQUE ESPECIAL E CONTA GARANTIDA
# FINANCIAMENTO - IMOBILIARIOS SFH
# FINANCIAMENTO - IMPORTACAO  E EXPORTACAO
# EMPRESTIMO - MICROCREDITO
# FINANCIAMENTO - MICROCREDITO
# FINANCIAMENTO - ARREENDAMENTO
# AVAIS E FIANCASA HONRADOS
# FINANCIAMENTO - IMOBILIARIO (OUTROS)
# CONSORCIO
# EMPRESTIMO - CONSIGNADO
# FINANCIAMENTO - AQUISICAO DE BENS (VEICULOS)
# OUTROS EMPRESTIMOS
# FINANCIAMENTO - RURAL E AGROINDUSTRIAL
# ['ADIANTAMENTO DEPOSITANTE', 'OUTROS FINANCIAMENTOS', 'CARTAO DE CREDITO', 'TITULOS DESCONTADOS', 'EMPRESTIMO - CAPITAL DE GIRO', 'EMPRESTIMO - CREDITO PESSOAL', 'CHEQUE ESPECIAL E CONTA GARANTIDA', 'FINANCIAMENTO - IMOBILIARIOS SFH', 'FINANCIAMENTO - IMPORTACAO  E EXPORTACAO', 'EMPRESTIMO - MICROCREDITO', 'FINANCIAMENTO - MICROCREDITO', 'FINANCIAMENTO - ARREENDAMENTO', 'AVAIS E FIANCASA HONRADOS', 'FINANCIAMENTO - IMOBILIARIO (OUTROS)', 'CONSORCIO', 'EMPRESTIMO - CONSIGNADO', 'FINANCIAMENTO - AQUISICAO DE BENS (VEICULOS)', 'OUTROS EMPRESTIMOS', 'FINANCIAMENTO - RURAL E AGROINDUSTRIAL']
# 0 14 CONSORCIO
# 1 1 OUTROS FINANCIAMENTOS
# 2 18 FINANCIAMENTO - RURAL E AGROINDUSTRIAL
# 3 7 FINANCIAMENTO - IMOBILIARIOS SFH
# 4 12 AVAIS E FIANCASA HONRADOS
# 5 11 FINANCIAMENTO - ARREENDAMENTO
# 6 5 EMPRESTIMO - CREDITO PESSOAL
# 7 16 FINANCIAMENTO - AQUISICAO DE BENS (VEICULOS)
# 8 9 EMPRESTIMO - MICROCREDITO
# 9 6 CHEQUE ESPECIAL E CONTA GARANTIDA
# 10 3 TITULOS DESCONTADOS
# 11 15 EMPRESTIMO - CONSIGNADO
# 12 17 OUTROS EMPRESTIMOS
# 13 13 FINANCIAMENTO - IMOBILIARIO (OUTROS)
# 14 2 CARTAO DE CREDITO
# c:\users\chatillon\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
df
# Out:
#     ID_STG_MVT_CRD  VLR_SDO_UTZ_CRD_RTO   VLR_TOT_FAT   VLR_MIM_FAT  \
# 0                1         0.000000e+00  0.000000e+00  0.000000e+00
# 1                2         0.000000e+00  0.000000e+00  0.000000e+00
# 2                3         0.000000e+00  0.000000e+00  0.000000e+00
# 3                4         0.000000e+00  0.000000e+00  0.000000e+00
# 4                5         0.000000e+00  0.000000e+00  0.000000e+00
# 5                6         0.000000e+00  0.000000e+00  0.000000e+00
# 6                7         0.000000e+00  0.000000e+00  0.000000e+00
# 7                8         0.000000e+00  0.000000e+00  0.000000e+00
# 8                9         0.000000e+00  0.000000e+00  0.000000e+00
# 9               10         2.181758e+10  0.000000e+00  0.000000e+00
# 10              11         0.000000e+00  0.000000e+00  0.000000e+00
# 11              12         0.000000e+00  0.000000e+00  0.000000e+00
# 12              13         0.000000e+00  0.000000e+00  0.000000e+00
# 13              14         0.000000e+00  0.000000e+00  0.000000e+00
# 14              15         0.000000e+00  1.932767e+12  6.071738e+11
#
#      VLR_PCL_FAT  QTD_CLI_CAD_POS   QTD_MVT DES_TIP_PSS  ID_FNT_ITT  \
# 0   4.595517e+08            37186    677272           F          67
# 1   7.387237e+08           307070   2741111           F          67
# 2   2.868181e+07              601      1964           F          67
# 3   6.111251e+08            18820    244041           F          67
# 4   2.152609e+04                2         4           F          67
# 5   4.607337e+06               33       329           F          67
# 6   2.638331e+09           721836  10020532           F          67
# 7   1.838029e+09           135773   1797516           F          67
# 8   9.738713e+06             5061     38003           F          67
# 9   0.000000e+00           194378    194921           F          67
# 10  9.496722e+07             1890    123559           F          67
# 11  3.556795e+09           494442  19241809           F          67
# 12  1.834447e+07            46495    230867           F          67
# 13  1.733950e+06               43       330           F          67
# 14  0.000000e+00          1840240  21748501           F          67
#
#                                          COD_MDL DAT_RSS_FNT_ITT  \
# 0                                      CONSORCIO      2020-01-16
# 1                          OUTROS FINANCIAMENTOS      2020-01-16
# 2         FINANCIAMENTO - RURAL E AGROINDUSTRIAL      2020-01-16
# 3               FINANCIAMENTO - IMOBILIARIOS SFH      2020-01-16
# 4                      AVAIS E FIANCASA HONRADOS      2020-01-16
# 5                  FINANCIAMENTO - ARREENDAMENTO      2020-01-16
# 6                   EMPRESTIMO - CREDITO PESSOAL      2020-01-16
# 7   FINANCIAMENTO - AQUISICAO DE BENS (VEICULOS)      2020-01-16
# 8                      EMPRESTIMO - MICROCREDITO      2020-01-16
# 9              CHEQUE ESPECIAL E CONTA GARANTIDA      2020-01-16
# 10                           TITULOS DESCONTADOS      2020-01-16
# 11                       EMPRESTIMO - CONSIGNADO      2020-01-16
# 12                            OUTROS EMPRESTIMOS      2020-01-16
# 13          FINANCIAMENTO - IMOBILIARIO (OUTROS)      2020-01-16
# 14                             CARTAO DE CREDITO      2020-01-16
#
#                 DAT_INC_DBO
# 0   2020-01-17 17:49:17.524
# 1   2020-01-17 17:49:17.524
# 2   2020-01-17 17:49:17.524
# 3   2020-01-17 17:49:17.524
# 4   2020-01-17 17:49:17.524
# 5   2020-01-17 17:49:17.524
# 6   2020-01-17 17:49:17.524
# 7   2020-01-17 17:49:17.524
# 8   2020-01-17 17:49:17.524
# 9   2020-01-17 17:49:17.524
# 10  2020-01-17 17:49:17.524
# 11  2020-01-17 17:49:17.524
# 12  2020-01-17 17:49:17.524
# 13  2020-01-17 17:49:17.524
# 14  2020-01-17 17:49:17.524

# %%
df.plot(kind='bar',x='COD_MDL', y='VLR_PCL_FAT', figsize = (15,8));
plt.title('Valor Total das Parcelas por Modalidade', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Valor Total das Parcelas por Modalidade')

# %%
df = df    
df.to_excel('output.xlsx')
